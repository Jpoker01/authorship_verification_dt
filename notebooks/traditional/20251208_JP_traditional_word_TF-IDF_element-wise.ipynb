# %%
import os
import time
import json
import pickle
import pandas as pd
import numpy as np
from functools import partial
import joblib

from datetime import datetime
from tqdm import tqdm
from dotenv import load_dotenv
from pathlib import Path

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics.pairwise import cosine_similarity

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

import torch

import optuna
import mlflow
from databricks.sdk import WorkspaceClient
# Out:
# /opt/conda/lib/python3.11/site-packages/torch/utils/_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Define path variables

# %%
representation_type = "traditional_word_TF-IDF_element-wise"
developer_initials = "JP"

# %%
current_dir = Path.cwd()
env_path = current_dir.parent.parent / "conf" / "local" / ".env"
results_path = current_dir.parent.parent / "results" / "traditional"

train_data_full_cleaned_path = current_dir.parent.parent / "data" /  "01_processed" / "pan20-authorship-verification-training-large-cleaned.jsonl"
validation_data_full_cleaned_path = current_dir.parent.parent / "data" /  "01_processed" / "pan20-authorship-verification-validation-large-cleaned.jsonl"
test_data_full_cleaned_path = current_dir.parent.parent / "data" /  "01_processed" / "pan21-authorship-verification-test-cleaned.jsonl"

# %% [markdown]
# Connect to databricks for logging results

# %%
load_dotenv(env_path)

w = WorkspaceClient()   
print("Connected to:", w.config.host)

mlflow.set_tracking_uri("databricks")
mlflow.autolog()
# Out:
# 2025/12/20 13:24:03 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 1.4.0 <= scikit-learn, but the installed version is 1.3.2. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# Connected to: https://dbc-1ea3ad0e-f504.cloud.databricks.com
# 2025/12/20 13:24:03 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2025/12/20 13:24:03 WARNING mlflow.utils.autologging_utils: MLflow statsmodels autologging is known to be compatible with 0.14.1 <= statsmodels, but the installed version is 0.14.0. If you encounter errors during autologging, try upgrading / downgrading statsmodels to a compatible version, or try upgrading MLflow.
# 2025/12/20 13:24:04 INFO mlflow.tracking.fluent: Autologging successfully enabled for statsmodels.
# 2025/12/20 13:24:04 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.

# %%
mlflow.sklearn.autolog(disable=True)
mlflow.xgboost.autolog(disable=True)

# %% [markdown]
# What are GPU are the experiments run on

# %%
# !nvidia-smi
# Out:
# Sat Dec 20 13:24:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A40                     Off |   00000000:27:00.0 Off |                    0 |
# |  0%   40C    P8             33W /  300W |       0MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
running_on_gpu = torch.cuda.is_available()

# %%
if running_on_gpu:
    gpu_name = torch.cuda.get_device_name(0)
    gpu_props = torch.cuda.get_device_properties(0)
    gpu_vram_gb = round(gpu_props.total_memory / (1024**3), 2)
else:
    gpu_name = "CPU"
    gpu_props = "N/A"
    gpu_vram_gb = 0

# %% [markdown]
# Empty the GPU from previous experiments

# %%
import gc
import torch
torch.cuda.empty_cache()
gc.collect()
# Out:
# 69

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %% [markdown]
# Classification threshold constant specification

# %%
classification_thresholds = [x/1000 for x in range(200, 999)]

# %% [markdown]
# TF-IDF parameters for tuning

# %%
maximum_features = [20_000, 50_000, 100_000, None]
lowercase = [False, True]
sublinear_tf = [True, False]
minimum_df = (1e-5, 0.01)

# %% [markdown]
# # Load dataset

# %% [markdown]
# #### Load training data

# %%
train_data_file_size = os.path.getsize(train_data_full_cleaned_path)
train_data = []

with open(train_data_full_cleaned_path, 'r') as f:
    with tqdm(total=train_data_file_size, desc="Loading data", unit='B', unit_scale=True) as pbar:
        for line in f:
            train_data.append(json.loads(line))
            pbar.update(len(line.encode('utf-8')))

print(f"\nSuccessfully loaded {len(train_data)} items.")
# Out:
# Loading data: 100%|██████████| 11.3G/11.3G [01:50<00:00, 102MB/s]
# Successfully loaded 273301 items.

# %%
train_data_df = pd.DataFrame(train_data)

# %% [markdown]
# Prepare dataset for cosine embedding loss

# %%
train_data_df.head(10)
# Out:
#                                      id  \
# 0  e05b9c0b-88a1-5608-b7e8-ab1fc6b78dc1
# 1  12f73a20-cdf3-58df-b5bb-9392eec9b486
# 2  d82c6764-451b-544c-8711-c139e9349c56
# 3  876b8380-9260-5427-93e8-dc31155c3edd
# 4  357e8471-35b9-50b4-9ac0-286ac0e8b101
# 5  6b39fe22-409f-5329-9fe1-ddf4a70bedd1
# 6  76ed2017-0c9f-580f-83b1-5a041a8169ec
# 7  fd8deb2e-06de-5c92-9a4c-927891c53657
# 8  3ce5e811-a57c-5fbf-9f9a-2ee636e50be6
# 9  25a17cd2-6b01-5fba-99ef-e631e56e181d
#
#                                                 pair   same
# 0  [Well, ever since you and Kurt broke up youve ...  False
# 1  [The thing is, Ryouga has no reason to run aft...  False
# 2  [Ehhhh nah, its silly' Its my job to listen to...   True
# 3  [Glaring at the arrogant spark, Always asks va...  False
# 4  [Runa limped across the small space to an open...  False
# 5  [And thats retired Commander, if you please St...  False
# 6  [Meet you downstairs in twenty minutes I say w...   True
# 7  [Since Ive seen so many others do so, Im going...  False
# 8  [party Eishi exclaimed Omi shook his head and ...  False
# 9  [After a few moments she found that Red was ri...  False

# %% [markdown]
# #### Load validation data

# %%
val_data_file_size = os.path.getsize(validation_data_full_cleaned_path)
val_data = []

with open(validation_data_full_cleaned_path, 'r') as f:
    with tqdm(total=val_data_file_size, desc="Loading data", unit='B', unit_scale=True) as pbar:
        for line in f:
            val_data.append(json.loads(line))
            pbar.update(len(line.encode('utf-8')))

print(f"\nSuccessfully loaded {len(val_data)} items.")
# Out:
# Loading data: 100%|██████████| 103M/103M [00:00<00:00, 116MB/s]
# Successfully loaded 2500 items.

# %%
val_data_df = pd.DataFrame(val_data)

# %% [markdown]
# #### Load testing data

# %%
test_data_file_size = os.path.getsize(test_data_full_cleaned_path)
test_data = []

with open(test_data_full_cleaned_path, 'r') as f:
    with tqdm(total=test_data_file_size, desc="Loading data", unit='B', unit_scale=True) as pbar:
        for line in f:
            test_data.append(json.loads(line))
            pbar.update(len(line.encode('utf-8')))

print(f"\nSuccessfully loaded {len(test_data)} items.")
# Out:
# Loading data: 100%|██████████| 826M/826M [00:07<00:00, 117MB/s]
# Successfully loaded 19999 items.

# %%
test_data_df = pd.DataFrame(test_data)

# %% [markdown]
# # Extract features functions

# %% [markdown]
# Build vectorizer function

# %%
def build_tfidf_vectorizer(max_features, min_df, lowercase=True, sublinear_tf=True):
    return TfidfVectorizer(
        analyzer="word",
        ngram_range=(1, 1),
        max_features=max_features,
        min_df=min_df,
        lowercase=lowercase,
        sublinear_tf=sublinear_tf,
        dtype=np.float32
    )

# %% [markdown]
# Function to fit the vectorizer & return trasnformed training and testing pairs of texts - two tuples with two lists with pairs at the same index

# %%
def build_tfidf_features(vectorizer, train_df, test_df):
    train_texts1 = train_df["pair"].apply(lambda x: x[0])
    train_texts2 = train_df["pair"].apply(lambda x: x[1])
    test_texts1 = test_df["pair"].apply(lambda x: x[0])
    test_texts2 = test_df["pair"].apply(lambda x: x[1])
    
    print("Fitting vectorizer \n")
    vectorizer.fit(pd.concat([train_texts1, train_texts2]))

    print("Transforming texts with vectorizer\n")
    X_train1 = vectorizer.transform(train_texts1)
    X_train2 = vectorizer.transform(train_texts2)
    X_test1 = vectorizer.transform(test_texts1)
    X_test2 = vectorizer.transform(test_texts2)

    X_train = (X_train1, X_train2)
    X_test = (X_test1, X_test2)
    
    return X_train, X_test

# %% [markdown]
# Function to return the absolute difference of two lists of transformed text

# %%
def compute_element_wise_features(X_pair):
    X_1, X_2 = X_pair
    return X_1.multiply(X_2)

# %% [markdown]
# # Evaluation functions

# %% [markdown]
# Evaluation function

# %%
def evaluate_results(y_true, y_pred, average='binary'):
    accuracy = round(accuracy_score(y_true, y_pred)*100, 2)
    precision = round(precision_score(y_true, y_pred, average=average, zero_division=0)*100, 2)
    recall = round(recall_score(y_true, y_pred, average=average)*100, 2)
    f1 = round(f1_score(y_true, y_pred, average=average)*100, 2)
    return accuracy, precision, recall, f1

# %% [markdown]
# Create the confusion matrix

# %%
def plot_confusion_matrix(y_true, y_pred, model_id="", labels=[False, True]):

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    
    fig, ax = plt.subplots(figsize=(6, 5))
    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        cmap='Blues',
        xticklabels=labels,
        yticklabels=labels,
        ax=ax,
        cbar=False
    )

    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')
    ax.set_title(f'Confusion Matrix: {model_id}')

    plt.tight_layout()
    return fig

# %% [markdown]
# Create histogram of F1 score for different thresholds

# %%
def plot_f1_vs_threshold(results_df):
    plt.figure(figsize=(9, 5))
    plt.plot(results_df["threshold"], results_df["f1"], linewidth=2)
    plt.xlabel("Threshold")
    plt.ylabel("F1 Score")
    plt.title("F1 Score vs Classification Threshold")
    plt.grid(True)
    plt.tight_layout()
    return plt.gcf()

# %% [markdown]
# # Classifier config setup for optuna studies

# %%
class ClassifierConfig: 
    def __init__(self, classifier_object, searched_hyperparameters, fixed_hyperparameters=None):
        self.classifier_object = classifier_object
        self.searched_hyperparameters = searched_hyperparameters or {}
        self.fixed_hyperparameters = fixed_hyperparameters or {}

    def sample_params(self, trial):
        sampled = {
            name: fn(trial)
            for name, fn in self.searched_hyperparameters.items()
        }
        sampled.update(self.fixed_hyperparameters)
        return sampled

# %% [markdown]
# # Optuna study function - for classifiers

# %%
def objective(trial, config):
    top_f1_trial = -1
    #get the vectorizer hyperparameters
    suggested_max_features = trial.suggest_categorical("max_features", maximum_features)
    suggested_min_df = trial.suggest_float("min_df", minimum_df[0], minimum_df[1])
    suggested_lowercase = trial.suggest_categorical("lowercase", lowercase)
    suggested_sublinear_tf = trial.suggest_categorical("sublinear_tf", sublinear_tf)
    
    #get the classifier hyperparameters
    classifier_params = config.sample_params(trial)
    
    #set up vectorizer
    vectorizer = build_tfidf_vectorizer(
        max_features=suggested_max_features,
        min_df=suggested_min_df, 
        lowercase=suggested_lowercase,
        sublinear_tf=suggested_sublinear_tf
        )
    
    #set up classifier
    classifier = config.classifier_object(**classifier_params)

    #fit the vectorizer and create features of training and test data
    train_data, val_data = build_tfidf_features(vectorizer, train_data_df, val_data_df)

    #compute the absolute differences between the pairs of features in train and test data
    train_data_diff = compute_element_wise_features(train_data)
    val_data_diff = compute_element_wise_features(val_data)

    #get the labels for train and test data
    y_train = train_data_df["same"].values
    y_test = val_data_df["same"].values
    
    #Fit the classifier
    classifier.fit(train_data_diff, y_train)
    
    #predict the labels for the test data
    y_pred = classifier.predict(val_data_diff)
    
    top_f1, top_accuracy, top_precision, top_recall = evaluate_results(y_test, y_pred)

    print(f"Logging results \n")
    print(f"Top f1: {top_f1}\n")
    print(f"Top accuracy: { top_accuracy}\n")
    print(f"Top precision: {top_precision}\n")
    print(f"Top recall: {top_recall}\n")

    print(f"Used hyperparameters \n")
    print(f"max_features: {suggested_max_features}\n")
    print(f"min_df: {suggested_min_df}\n")
    print(f"lowercase: {suggested_lowercase}\n")
    print(f"sublinear_tf: {suggested_sublinear_tf}\n")
    

    trial.set_user_attr(
    "results",
    {
    "metrics": {
        "top_f1": top_f1,
        "top_accuracy": top_accuracy,
        "top_precision": top_precision,
        "top_recall": top_recall
        },
    "hyperparameters": {
        "max_features": suggested_max_features,
        "min_df": suggested_min_df,
        "lowercase": suggested_lowercase,
        "sublinear_tf": suggested_sublinear_tf
        },
    "classifier_hyperparameters": {
            **classifier_params
        },
    }
    )
    print(classifier_params)

    del train_data, val_data, vectorizer, classifier
    gc.collect()
    
    return top_f1

# %% [markdown]
# # Evaluate model hyperparameters - Multinomial naïve Bayes

# %%
classifier_name = "multinomial_naive_bayes"

# %%
multinomial_naive_bayes_config = ClassifierConfig(
    classifier_object=MultinomialNB,
    searched_hyperparameters={
        "alpha": lambda trial: trial.suggest_float("alpha", 1e-3, 1.0, log=True)
    },
    fixed_hyperparameters={}
)

# %% [markdown]
# Set up the study

# %%
optuna_study_path = f"sqlite:///optuna_study_{developer_initials}_{representation_type}_{classifier_name}"

study = optuna.create_study(
    study_name=f"authorship_verification_{representation_type}_{classifier_name}",
    storage=optuna_study_path,
    direction="maximize",
    load_if_exists=True
)

# %%
study.optimize(lambda trial: objective(trial, multinomial_naive_bayes_config), n_trials=30)

# %% [markdown]
# Save the study insights

# %%
best_trial = study.best_trial
best_params = best_trial.params

date_str = datetime.now().strftime("%Y%m%d_%H%M")

trial_results_path = current_dir.parent.parent / "data" / "02_models" / "traditional" / f"{developer_initials}_{representation_type}_{classifier_name}_trial_results.json"
finetuned_model_best_params = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_parameters.json"
finetuned_vectorizer_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_vectorizer.pkl"
finetuned_model_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_model.pkl"

# %% [markdown]
# Load the trial data

# %%
trial_rows = []

for trial in study.trials:
    if "results" not in trial.user_attrs:
        continue
    
    metrics = trial.user_attrs["results"]["metrics"]
    hyper_params = trial.user_attrs["results"]["hyperparameters"]
    classifier_hyper_params = trial.user_attrs["results"]["classifier_hyperparameters"]
    
    row = {
        "trial_number": trial.number,
        "top_f1": metrics["top_f1"],
        "top_accuracy": metrics["top_accuracy"],
        "top_precision": metrics["top_precision"],
        "top_recall": metrics["top_recall"],
        
        **{f"{key}": v for key, v in hyper_params.items()},
        **{f"{key}": v for key, v in classifier_hyper_params.items()},
        
    }
    trial_rows.append(row)

trial_results_df = pd.DataFrame(trial_rows)
trial_results_df.head()

# %%
with open(finetuned_model_best_params, "w") as f:
    json.dump(best_params, f, indent=4)

# %%
with open(trial_results_path, "w") as f:
    json.dump(trial_results_df.to_dict(orient="records"), f, indent=4)

# %% [markdown]
# # Train the final model - Multinomial naïve Bayes

# %%
best_params = {}
trial_results = {}

# %%
with open(finetuned_model_best_params, "r") as f:
    best_params = json.load(f)

# %%
with open(trial_results_path, "r") as f:
    trial_results = json.load(f)

# %%
trial_results_df = pd.DataFrame(trial_results)

# %%
top_max_features = best_params["max_features"]
top_min_df = best_params["min_df"]
top_lowercase = best_params["lowercase"]
top_sublinear_tf  = best_params["sublinear_tf"]

top_alpha = best_params["alpha"]

# %%
print(f"Used hyperparameters \n")
print(f"max_features: {top_max_features}\n")
print(f"min_df: {top_min_df}\n")
print(f"lowercase: {top_lowercase}\n")
print(f"sublinear_tf: {top_sublinear_tf}\n")

print(f"top_alpha: {top_alpha}\n")

# %% [markdown]
# Reconstruct the best vectorizer

# %%
best_vectorizer = build_tfidf_vectorizer(
        max_features=top_max_features,
        min_df=top_min_df, 
        lowercase=top_lowercase,
        sublinear_tf=top_sublinear_tf
        )

# %% [markdown]
# Combine validation and training dataset

# %%
final_train_df = pd.concat(
    [train_data_df, val_data_df],
    ignore_index=True
)

# %% [markdown]
# Fit the vectorizer and create features of training and test data

# %%
train_data, test_data = build_tfidf_features(best_vectorizer, final_train_df, test_data_df)

# %% [markdown]
# Compute the absolute differences between the pairs of features in train and test data

# %%
train_data_diff = compute_element_wise_features(train_data)
test_data_diff = compute_element_wise_features(test_data)

# %% [markdown]
# Get the labels for train and test data

# %%
y_train = final_train_df["same"].values
y_test = test_data_df["same"].values

# %% [markdown]
# Fit the classifier

# %%
classifier = MultinomialNB(alpha=top_alpha)
classifier.fit(train_data_diff, y_train)

# %% [markdown]
# Predict the labels for the test data

# %%
y_pred = classifier.predict(test_data_diff)

# %% [markdown]
# Evaluate the results of the final classifier

# %%
top_f1, top_accuracy, top_precision, top_recall = evaluate_results(y_test, y_pred)

print(f"Logging results \n")
print(f"Top f1: {top_f1}\n")
print(f"Top accuracy: { top_accuracy}\n")
print(f"Top precision: {top_precision}\n")
print(f"Top recall: {top_recall}\n")

# %% [markdown]
# Save the final vectorizer and classifier

# %%
joblib.dump(best_vectorizer, finetuned_vectorizer_path)
joblib.dump(classifier, finetuned_model_path)

# %% [markdown]
# Confusion matrix

# %%
cm_fig = plot_confusion_matrix(y_test , y_pred, f"{representation_type}_{classifier_name}", labels=[False, True])

# %% [markdown]
# Log model information + metrics + results table + confusion matrix

# %%
mlflow.set_experiment("/Users/jiripokorny455@gmail.com/JP_authorship_verification_dt")
with mlflow.start_run(run_name=f"{developer_initials}_{representation_type}_{classifier_name}"):
    mlflow.log_param("gpu_name", gpu_name)
    mlflow.log_param("gpu_vram_gb", gpu_vram_gb)
    
    mlflow.log_param("representation_type", representation_type )
    mlflow.log_param("classifier", classifier_name)
    mlflow.log_table(data=trial_results_df, artifact_file="trial_results.json")
    
    mlflow.log_param("max_features", top_max_features)
    mlflow.log_param("min_df", top_min_df)
    mlflow.log_param("lowercase", top_lowercase)
    mlflow.log_param("sublinear_tf", top_sublinear_tf)
    mlflow.log_param("alpha", top_alpha)

    mlflow.log_metric("top_accuracy", top_accuracy)
    mlflow.log_metric("top_precision", top_precision)
    mlflow.log_metric("top_recall", top_recall)
    mlflow.log_metric("top_f1", top_f1)

    mlflow.log_figure(cm_fig, "confusion_matrix-test_data.png")

# %% [markdown]
# # Evaluate model hyperparameters - Logistic regression

# %%
classifier_name = "logistic_regression"

# %% [markdown]
# Resolving the penalty parameter - for both types only certain solvers are possible

# %%
logigistic_regression_config = ClassifierConfig(
    classifier_object=LogisticRegression,
    searched_hyperparameters={
        "C": lambda trial: trial.suggest_float("C", 0.01, 5.0, log=True),
        "penalty": lambda trial: trial.suggest_categorical("penalty", ["l1", "l2"]),
        "solver": lambda trial: trial.suggest_categorical("solver", ["liblinear", "saga"]),
    },
    fixed_hyperparameters={
        "max_iter": 5000,
        "n_jobs": -1 #uses all cores
    }
)

# %% [markdown]
# Set up the study

# %%
optuna_study_path = f"sqlite:///optuna_study_{developer_initials}_{representation_type}_{classifier_name}"

study = optuna.create_study(
    study_name=f"authorship_verification_{representation_type}_{classifier_name}",
    storage=optuna_study_path,
    direction="maximize",
    load_if_exists=True
)

# %%
len(study.trials)

# %% [markdown]
# study.optimize(lambda trial: objective(trial, logigistic_regression_config), n_trials=30)

# %% [markdown]
# Save the study insights

# %%
best_trial = study.best_trial
best_params = best_trial.params
best_params.update({
    "max_iter": 5000,
    "n_jobs": -1
})

# %%
date_str = datetime.now().strftime("%Y%m%d_%H%M")

trial_results_path = current_dir.parent.parent / "data" / "02_models" / "traditional" / f"{developer_initials}_{representation_type}_{classifier_name}_trial_results.json"
finetuned_model_best_params = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_parameters.json"
finetuned_vectorizer_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_vectorizer.pkl"
finetuned_model_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_model.pkl"

# %% [markdown]
# Load the trial data

# %%
trial_rows = []

for trial in study.trials:
    
    if "results" not in trial.user_attrs:
        continue 
        
    metrics = trial.user_attrs["results"]["metrics"]
    hyper_params = trial.user_attrs["results"]["hyperparameters"]
    classifier_hyper_params = trial.user_attrs["results"]["classifier_hyperparameters"]
    
    row = {
        "trial_number": trial.number,
        "top_f1": metrics["top_f1"],
        "top_accuracy": metrics["top_accuracy"],
        "top_precision": metrics["top_precision"],
        "top_recall": metrics["top_recall"],
        
        **{f"{key}": v for key, v in hyper_params.items()},
        **{f"{key}": v for key, v in classifier_hyper_params.items()},
        
    }
    trial_rows.append(row)

trial_results_df = pd.DataFrame(trial_rows)
trial_results_df.head()

# %%
with open(finetuned_model_best_params, "w") as f:
    json.dump(best_params, f, indent=4)

# %%
with open(trial_results_path, "w") as f:
    json.dump(trial_results_df.to_dict(orient="records"), f, indent=4)

# %% [markdown]
# # Train the final model - Logistic regression

# %%
best_params = {}
trial_results = {}

# %%
with open(finetuned_model_best_params, "r") as f:
    best_params = json.load(f)

# %%
print(best_params)

# %%
with open(trial_results_path, "r") as f:
    trial_results = json.load(f)

# %%
trial_results_df = pd.DataFrame(trial_results)

# %%
top_max_features = best_params["max_features"]
top_min_df = best_params["min_df"]
top_lowercase = best_params["lowercase"]
top_sublinear_tf  = best_params["sublinear_tf"]

top_c = best_params["C"]
top_penalty = best_params["penalty"]
top_solver = best_params["solver"]
top_max_iter = best_params["max_iter"]
top_n_jobs = best_params["n_jobs"]

# %%
print(f"Used hyperparameters \n")
print(f"max_features: {top_max_features}\n")
print(f"min_df: {top_min_df}\n")
print(f"lowercase: {top_lowercase}\n")
print(f"sublinear_tf: {top_sublinear_tf}\n")
print(f"c: {top_c}\n")
print(f"penalty: {top_penalty}\n")
print(f"solver: {top_solver}\n")
print(f"max_iter: {top_max_iter}\n")
print(f"n_jobs: {top_n_jobs}\n")

# %% [markdown]
# Reconstruct the best vectorizer

# %%
best_vectorizer = build_tfidf_vectorizer(
        max_features=top_max_features,
        min_df=top_min_df, 
        lowercase=top_lowercase,
        sublinear_tf=top_sublinear_tf
        )

# %% [markdown]
# Combine validation and training dataset

# %%
final_train_df = pd.concat(
    [train_data_df, val_data_df],
    ignore_index=True
)

# %% [markdown]
# Fit the vectorizer and create features of training and test data

# %%
train_data, test_data = build_tfidf_features(best_vectorizer, final_train_df, test_data_df)

# %% [markdown]
# Compute the absolute differences between the pairs of features in train and test data

# %%
train_data_diff = compute_element_wise_features(train_data)
test_data_diff = compute_element_wise_features(test_data)

# %% [markdown]
# Get the labels for train and test data

# %%
y_train = final_train_df["same"].values
y_test = test_data_df["same"].values

# %% [markdown]
# Fit the classifier

# %%
classifier = LogisticRegression(
    C=top_c,
    penalty=top_penalty,
    solver=top_solver,
    max_iter=top_max_iter,
    n_jobs=top_n_jobs
)
classifier.fit(train_data_diff, y_train)

# %% [markdown]
# Predict the labels for the test data

# %%
y_pred = classifier.predict(test_data_diff)

# %% [markdown]
# Evaluate the results of the final classifier

# %%
top_f1, top_accuracy, top_precision, top_recall = evaluate_results(y_test, y_pred)

print(f"Logging results \n")
print(f"Top f1: {top_f1}\n")
print(f"Top accuracy: { top_accuracy}\n")
print(f"Top precision: {top_precision}\n")
print(f"Top recall: {top_recall}\n")

# %% [markdown]
# Save the final vectorizer and classifier

# %%
joblib.dump(best_vectorizer, finetuned_vectorizer_path)
joblib.dump(classifier, finetuned_model_path)

# %% [markdown]
# Confusion matrix

# %%
cm_fig = plot_confusion_matrix(y_test , y_pred, f"{representation_type}_{classifier_name}", labels=[False, True])

# %% [markdown]
# Log model information + metrics + results table + confusion matrix

# %%
mlflow.set_experiment("/Users/jiripokorny455@gmail.com/JP_authorship_verification_dt")
with mlflow.start_run(run_name=f"{developer_initials}_{representation_type}_{classifier_name}"):
    mlflow.log_param("gpu_name", gpu_name)
    mlflow.log_param("gpu_vram_gb", gpu_vram_gb)
    
    mlflow.log_param("representation_type", representation_type )
    mlflow.log_param("classifier", classifier_name)
    mlflow.log_table(data=trial_results_df, artifact_file="trial_results.json")
    
    mlflow.log_param("max_features", top_max_features)
    mlflow.log_param("min_df", top_min_df)
    mlflow.log_param("lowercase", top_lowercase)
    mlflow.log_param("sublinear_tf", top_sublinear_tf)
    
    mlflow.log_param("C", top_c)
    mlflow.log_param("penalty", top_penalty)
    mlflow.log_param("solver", top_solver)
    mlflow.log_param("max_iter", top_max_iter)
    mlflow.log_param("n_jobs", top_n_jobs)

    mlflow.log_metric("top_accuracy", top_accuracy)
    mlflow.log_metric("top_precision", top_precision)
    mlflow.log_metric("top_recall", top_recall)
    mlflow.log_metric("top_f1", top_f1)

    mlflow.log_figure(cm_fig, "confusion_matrix-test_data.png")

# %% [markdown]
# # Evaluate model hyperparameters - Linear SVC

# %%
classifier_name = "linear_svc"

# %%
linear_svc_config = ClassifierConfig(
    classifier_object=LinearSVC,
    searched_hyperparameters={
        "C": lambda trial: trial.suggest_float("C", 0.01, 5.0, log=True),
        "loss": lambda trial: trial.suggest_categorical("loss", ["hinge", "squared_hinge"]),
        "class_weight": lambda trial: trial.suggest_categorical("class_weight", [None, "balanced"]),
    },
    fixed_hyperparameters={
        "penalty": "l2",       # LinearSVC ONLY supports l2
        "dual": True,          # for high-dimensional data (TF-IDF)
        "max_iter": 5000       # ensure convergence
    }
)

# %% [markdown]
# Set up the study

# %%
optuna_study_path = f"sqlite:///optuna_study_{developer_initials}_{representation_type}_{classifier_name}"

study = optuna.create_study(
    study_name=f"authorship_verification_{representation_type}_{classifier_name}",
    storage=optuna_study_path,
    direction="maximize",
    load_if_exists=True
)

# %%
study.optimize(lambda trial: objective(trial, linear_svc_config), n_trials=30)

# %% [markdown]
# Save the study insights

# %%
best_trial = study.best_trial
best_params = best_trial.params
best_params.update({
    "penalty": "l2",       
    "dual": True,          
    "max_iter": 5000
})

# %%
trial_results_path = current_dir.parent.parent / "data" / "02_models" / "traditional" / f"{developer_initials}_{representation_type}_{classifier_name}_trial_results.json"
finetuned_model_best_params = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_parameters.json"
finetuned_vectorizer_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_vectorizer.pkl"
finetuned_model_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_model.pkl"

# %% [markdown]
# Load the trial data

# %%
trial_rows = []

for trial in study.trials:
    
    if "results" not in trial.user_attrs:
        continue 
        
    metrics = trial.user_attrs["results"]["metrics"]
    hyper_params = trial.user_attrs["results"]["hyperparameters"]
    classifier_hyper_params = trial.user_attrs["results"]["classifier_hyperparameters"]
    
    row = {
        "trial_number": trial.number,
        "top_f1": metrics["top_f1"],
        "top_accuracy": metrics["top_accuracy"],
        "top_precision": metrics["top_precision"],
        "top_recall": metrics["top_recall"],
        
        **{f"{key}": v for key, v in hyper_params.items()},
        **{f"{key}": v for key, v in classifier_hyper_params.items()},
        
    }
    trial_rows.append(row)

trial_results_df = pd.DataFrame(trial_rows)
trial_results_df.head()

# %%
with open(finetuned_model_best_params, "w") as f:
    json.dump(best_params, f, indent=4)

# %%
with open(trial_results_path, "w") as f:
    json.dump(trial_results_df.to_dict(orient="records"), f, indent=4)

# %% [markdown]
# # Train the final model - Linear SVC

# %%
best_params = {}
trial_results = {}

# %%
with open(finetuned_model_best_params, "r") as f:
    best_params = json.load(f)

# %%
with open(trial_results_path, "r") as f:
    trial_results = json.load(f)

# %%
trial_results_df = pd.DataFrame(trial_results)

# %%
top_max_features = best_params["max_features"]
top_min_df = best_params["min_df"]
top_lowercase = best_params["lowercase"]
top_sublinear_tf  = best_params["sublinear_tf"]

top_c = best_params["C"]
top_loss = best_params["loss"]
top_class_weight = best_params["class_weight"]
top_penalty = best_params["penalty"]
top_dual = best_params["dual"]
top_max_iter = best_params["max_iter"]

# %%
print(f"Used hyperparameters \n")
print(f"max_features: {top_max_features}\n")
print(f"min_df: {top_min_df}\n")
print(f"lowercase: {top_lowercase}\n")
print(f"sublinear_tf: {top_sublinear_tf}\n")

print(f"c: {top_c}\n")
print(f"loss: {top_loss}\n")
print(f"class_weight: {top_class_weight}\n")
print(f"penalty: {top_penalty}\n")
print(f"dual: {top_dual}\n")
print(f"max_iter: {top_max_iter}\n")

# %% [markdown]
# Reconstruct the best vectorizer

# %%
best_vectorizer = build_tfidf_vectorizer(
        max_features=top_max_features,
        min_df=top_min_df, 
        lowercase=top_lowercase,
        sublinear_tf=top_sublinear_tf
        )

# %% [markdown]
# Combine validation and training dataset

# %%
final_train_df = pd.concat(
    [train_data_df, val_data_df],
    ignore_index=True
)

# %% [markdown]
# Fit the vectorizer and create features of training and test data

# %%
train_data, test_data = build_tfidf_features(best_vectorizer, final_train_df, test_data_df)

# %% [markdown]
# Compute the absolute differences between the pairs of features in train and test data

# %%
train_data_diff = compute_element_wise_features(train_data)
test_data_diff = compute_element_wise_features(test_data)

# %% [markdown]
# Get the labels for train and test data

# %%
y_train = final_train_df["same"].values
y_test = test_data_df["same"].values

# %% [markdown]
# Fit the classifier

# %%
classifier = LinearSVC(
    C=top_c,
    loss=top_loss,
    class_weight=top_class_weight,
    penalty=top_penalty,
    dual=top_dual,
    max_iter=top_max_iter
)

classifier.fit(train_data_diff, y_train)

# %% [markdown]
# Predict the labels for the test data

# %%
y_pred = classifier.predict(test_data_diff)

# %% [markdown]
# Evaluate the results of the final classifier

# %%
top_f1, top_accuracy, top_precision, top_recall = evaluate_results(y_test, y_pred)

print(f"Logging results \n")
print(f"Top f1: {top_f1}\n")
print(f"Top accuracy: { top_accuracy}\n")
print(f"Top precision: {top_precision}\n")
print(f"Top recall: {top_recall}\n")

# %% [markdown]
# Save the final vectorizer and classifier

# %%
joblib.dump(best_vectorizer, finetuned_vectorizer_path)
joblib.dump(classifier, finetuned_model_path)

# %% [markdown]
# Confusion matrix

# %%
cm_fig = plot_confusion_matrix(y_test , y_pred, f"{representation_type}_{classifier_name}", labels=[False, True])

# %% [markdown]
# Log model information + metrics + results table + confusion matrix

# %%
mlflow.set_experiment("/Users/jiripokorny455@gmail.com/JP_authorship_verification_dt")
with mlflow.start_run(run_name=f"{developer_initials}_{representation_type}_{classifier_name}"):
    mlflow.log_param("gpu_name", gpu_name)
    mlflow.log_param("gpu_vram_gb", gpu_vram_gb)
    
    mlflow.log_param("representation_type", representation_type )
    mlflow.log_param("classifier", classifier_name)
    mlflow.log_table(data=trial_results_df, artifact_file="trial_results.json")
    
    mlflow.log_param("max_features", top_max_features)
    mlflow.log_param("min_df", top_min_df)
    mlflow.log_param("lowercase", top_lowercase)
    mlflow.log_param("sublinear_tf", top_sublinear_tf)
                    
    mlflow.log_param("C", top_c)
    mlflow.log_param("loss", top_loss)
    mlflow.log_param("class_weight", top_class_weight)
    mlflow.log_param("penalty", top_penalty)
    mlflow.log_param("dual", top_dual)
    mlflow.log_param("max_iter", top_max_iter)

    mlflow.log_metric("top_accuracy", top_accuracy)
    mlflow.log_metric("top_precision", top_precision)
    mlflow.log_metric("top_recall", top_recall)
    mlflow.log_metric("top_f1", top_f1)

    mlflow.log_figure(cm_fig, "confusion_matrix-test_data.png")

# %% [markdown]
# # Evaluate model hyperparameters - K-nearest neighbors

# %%
classifier_name = "k-nearest_neighbors"

# %%
knn_config = ClassifierConfig(
    classifier_object=KNeighborsClassifier,
    searched_hyperparameters={
        "n_neighbors": lambda trial: trial.suggest_int("n_neighbors", 1, 50),
        "weights": lambda trial: trial.suggest_categorical("weights", ["uniform", "distance"]),
        "metric": lambda trial: trial.suggest_categorical("metric", ["euclidean", "manhattan", "cosine"]),
    },
    fixed_hyperparameters={
        "algorithm": "auto"
    }
)

# %% [markdown]
# Set up the study

# %%
optuna_study_path = f"sqlite:///optuna_study_{developer_initials}_{representation_type}_{classifier_name}"

study = optuna.create_study(
    study_name=f"authorship_verification_{representation_type}_{classifier_name}",
    storage=optuna_study_path,
    direction="maximize",
    load_if_exists=True
)
# Out:
# [I 2025-12-19 12:19:49,406] Using an existing study with name 'authorship_verification_traditional_word_TF-IDF_element-wise_k-nearest_neighbors' instead of creating a new one.

# %%
study.optimize(lambda trial: objective(trial, knn_config), n_trials=30 - len(study.trials))
# Out:
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 48.12
#
# Top accuracy: 100.0
#
# Top precision: 2.99
#
# Top recall: 5.81
#
# Used hyperparameters
#
# max_features: 20000
#
# min_df: 0.0007120876404348595
#
# lowercase: True
#
# sublinear_tf: True
#
# {'n_neighbors': 13, 'weights': 'distance', 'metric': 'manhattan', 'algorithm': 'auto'}
# [I 2025-12-19 12:48:59,792] Trial 11 finished with value: 48.12 and parameters: {'max_features': 20000, 'min_df': 0.0007120876404348595, 'lowercase': True, 'sublinear_tf': True, 'n_neighbors': 13, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 58.6
#
# Top accuracy: 93.64
#
# Top precision: 24.23
#
# Top recall: 38.5
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.009708898370328721
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 20, 'weights': 'distance', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 13:15:41,792] Trial 12 finished with value: 58.6 and parameters: {'max_features': None, 'min_df': 0.009708898370328721, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 20, 'weights': 'distance', 'metric': 'cosine'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 58.6
#
# Top accuracy: 71.03
#
# Top precision: 38.15
#
# Top recall: 49.64
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.009645926026675637
#
# lowercase: True
#
# sublinear_tf: False
#
# {'n_neighbors': 2, 'weights': 'uniform', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 13:41:32,771] Trial 13 finished with value: 58.6 and parameters: {'max_features': None, 'min_df': 0.009645926026675637, 'lowercase': True, 'sublinear_tf': False, 'n_neighbors': 2, 'weights': 'uniform', 'metric': 'cosine'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 63.92
#
# Top accuracy: 71.82
#
# Top precision: 53.55
#
# Top recall: 61.35
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.0073506000058402975
#
# lowercase: True
#
# sublinear_tf: False
#
# {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 14:07:14,567] Trial 14 finished with value: 63.92 and parameters: {'max_features': None, 'min_df': 0.0073506000058402975, 'lowercase': True, 'sublinear_tf': False, 'n_neighbors': 50, 'weights': 'uniform', 'metric': 'cosine'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 60.4
#
# Top accuracy: 64.09
#
# Top precision: 59.01
#
# Top recall: 61.45
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.004492598552106228
#
# lowercase: True
#
# sublinear_tf: False
#
# {'n_neighbors': 1, 'weights': 'uniform', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 14:33:04,934] Trial 15 finished with value: 60.4 and parameters: {'max_features': None, 'min_df': 0.004492598552106228, 'lowercase': True, 'sublinear_tf': False, 'n_neighbors': 1, 'weights': 'uniform', 'metric': 'cosine'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 57.68
#
# Top accuracy: 92.92
#
# Top precision: 22.59
#
# Top recall: 36.34
#
# Used hyperparameters
#
# max_features: 20000
#
# min_df: 0.008284484337165325
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 22, 'weights': 'distance', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 15:01:09,472] Trial 16 finished with value: 57.68 and parameters: {'max_features': 20000, 'min_df': 0.008284484337165325, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 22, 'weights': 'distance', 'metric': 'cosine'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 62.32
#
# Top accuracy: 70.51
#
# Top precision: 50.79
#
# Top recall: 59.04
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.004791258432729939
#
# lowercase: True
#
# sublinear_tf: False
#
# {'n_neighbors': 16, 'weights': 'uniform', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 15:27:37,232] Trial 17 finished with value: 62.32 and parameters: {'max_features': None, 'min_df': 0.004791258432729939, 'lowercase': True, 'sublinear_tf': False, 'n_neighbors': 16, 'weights': 'uniform', 'metric': 'cosine'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 46.6
#
# Top accuracy: 100.0
#
# Top precision: 0.15
#
# Top recall: 0.3
#
# Used hyperparameters
#
# max_features: 20000
#
# min_df: 0.0035383948043909387
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 48, 'weights': 'distance', 'metric': 'manhattan', 'algorithm': 'auto'}
# [I 2025-12-19 15:59:20,581] Trial 18 finished with value: 46.6 and parameters: {'max_features': 20000, 'min_df': 0.0035383948043909387, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 48, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 63.68
#
# Top accuracy: 71.17
#
# Top precision: 53.93
#
# Top recall: 61.36
#
# Used hyperparameters
#
# max_features: 50000
#
# min_df: 0.007944068041368237
#
# lowercase: True
#
# sublinear_tf: False
#
# {'n_neighbors': 38, 'weights': 'uniform', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 16:28:50,443] Trial 19 finished with value: 63.68 and parameters: {'max_features': 50000, 'min_df': 0.007944068041368237, 'lowercase': True, 'sublinear_tf': False, 'n_neighbors': 38, 'weights': 'uniform', 'metric': 'cosine'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 64.64
#
# Top accuracy: 71.93
#
# Top precision: 55.57
#
# Top recall: 62.7
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.006155346825891807
#
# lowercase: False
#
# sublinear_tf: False
#
# {'n_neighbors': 26, 'weights': 'distance', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 16:56:00,117] Trial 20 finished with value: 64.64 and parameters: {'max_features': None, 'min_df': 0.006155346825891807, 'lowercase': False, 'sublinear_tf': False, 'n_neighbors': 26, 'weights': 'distance', 'metric': 'cosine'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 46.68
#
# Top accuracy: 100.0
#
# Top precision: 0.3
#
# Top recall: 0.6
#
# Used hyperparameters
#
# max_features: 20000
#
# min_df: 0.008707847234562862
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 25, 'weights': 'distance', 'metric': 'manhattan', 'algorithm': 'auto'}
# [I 2025-12-19 17:27:28,075] Trial 21 finished with value: 46.68 and parameters: {'max_features': 20000, 'min_df': 0.008707847234562862, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 25, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 69.0
#
# Top accuracy: 94.32
#
# Top precision: 44.73
#
# Top recall: 60.68
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.006166760360683765
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 6, 'weights': 'distance', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 17:54:29,524] Trial 22 finished with value: 69.0 and parameters: {'max_features': None, 'min_df': 0.006166760360683765, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 6, 'weights': 'distance', 'metric': 'cosine'}. Best is trial 9 with value: 72.56.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 72.68
#
# Top accuracy: 94.79
#
# Top precision: 51.76
#
# Top recall: 66.96
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.006602360499193791
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 4, 'weights': 'distance', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 18:21:32,597] Trial 23 finished with value: 72.68 and parameters: {'max_features': None, 'min_df': 0.006602360499193791, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 4, 'weights': 'distance', 'metric': 'cosine'}. Best is trial 23 with value: 72.68.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 68.76
#
# Top accuracy: 94.27
#
# Top precision: 44.28
#
# Top recall: 60.25
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.00724006751571618
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 6, 'weights': 'distance', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 18:48:56,776] Trial 24 finished with value: 68.76 and parameters: {'max_features': None, 'min_df': 0.00724006751571618, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 6, 'weights': 'distance', 'metric': 'cosine'}. Best is trial 23 with value: 72.68.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 69.08
#
# Top accuracy: 94.62
#
# Top precision: 44.73
#
# Top recall: 60.74
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.005458398801032993
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 6, 'weights': 'distance', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 19:16:09,617] Trial 25 finished with value: 69.08 and parameters: {'max_features': None, 'min_df': 0.005458398801032993, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 6, 'weights': 'distance', 'metric': 'cosine'}. Best is trial 23 with value: 72.68.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 68.52
#
# Top accuracy: 94.93
#
# Top precision: 43.46
#
# Top recall: 59.62
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.005050978232225222
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 5, 'weights': 'distance', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 19:43:00,211] Trial 26 finished with value: 68.52 and parameters: {'max_features': None, 'min_df': 0.005050978232225222, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 5, 'weights': 'distance', 'metric': 'cosine'}. Best is trial 23 with value: 72.68.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 63.76
#
# Top accuracy: 95.37
#
# Top precision: 33.88
#
# Top recall: 50.0
#
# Used hyperparameters
#
# max_features: 20000
#
# min_df: 0.008943586324839612
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 10, 'weights': 'distance', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 20:11:55,762] Trial 27 finished with value: 63.76 and parameters: {'max_features': 20000, 'min_df': 0.008943586324839612, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 10, 'weights': 'distance', 'metric': 'cosine'}. Best is trial 23 with value: 72.68.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 59.44
#
# Top accuracy: 92.17
#
# Top precision: 26.4
#
# Top recall: 41.05
#
# Used hyperparameters
#
# max_features: 50000
#
# min_df: 0.007235845698771445
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 15, 'weights': 'distance', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 20:40:41,997] Trial 28 finished with value: 59.44 and parameters: {'max_features': 50000, 'min_df': 0.007235845698771445, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 15, 'weights': 'distance', 'metric': 'cosine'}. Best is trial 23 with value: 72.68.
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 73.2
#
# Top accuracy: 94.89
#
# Top precision: 52.73
#
# Top recall: 67.79
#
# Used hyperparameters
#
# max_features: 100000
#
# min_df: 0.004017693739287494
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_neighbors': 4, 'weights': 'distance', 'metric': 'cosine', 'algorithm': 'auto'}
# [I 2025-12-19 21:09:22,895] Trial 29 finished with value: 73.2 and parameters: {'max_features': 100000, 'min_df': 0.004017693739287494, 'lowercase': False, 'sublinear_tf': True, 'n_neighbors': 4, 'weights': 'distance', 'metric': 'cosine'}. Best is trial 29 with value: 73.2.

# %% [markdown]
# Save the study insights

# %%
best_trial = study.best_trial
best_params = best_trial.params

best_trial = study.best_trial
best_params = best_trial.params
best_params.update({
    "algorithm": "auto"
})

# %%
trial_results_path = current_dir.parent.parent / "data" / "02_models" / "traditional" / f"{developer_initials}_{representation_type}_{classifier_name}_trial_results.json"
finetuned_model_best_params = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_parameters.json"
finetuned_vectorizer_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_vectorizer.pkl"
finetuned_model_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_model.pkl"

# %% [markdown]
# Load the trial data

# %%
trial_rows = []

for trial in study.trials:
    
    if "results" not in trial.user_attrs:
        continue 
        
    metrics = trial.user_attrs["results"]["metrics"]
    hyper_params = trial.user_attrs["results"]["hyperparameters"]
    classifier_hyper_params = trial.user_attrs["results"]["classifier_hyperparameters"]
    
    row = {
        "trial_number": trial.number,
        "top_f1": metrics["top_f1"],
        "top_accuracy": metrics["top_accuracy"],
        "top_precision": metrics["top_precision"],
        "top_recall": metrics["top_recall"],
        
        **{f"{key}": v for key, v in hyper_params.items()},
        **{f"{key}": v for key, v in classifier_hyper_params.items()},
        
    }
    trial_rows.append(row)

trial_results_df = pd.DataFrame(trial_rows)
trial_results_df.head()
# Out:
#    trial_number  top_f1  top_accuracy  top_precision  top_recall  \
# 0             0   56.84         89.81          21.77       35.04
# 1             1   60.56         69.70          46.45       55.75
# 2             3   56.60         83.16          23.64       36.81
# 3             4   62.44         69.82          52.43       59.89
# 4             5   49.04         81.82           6.06       11.28
#
#    max_features    min_df  lowercase  sublinear_tf  n_neighbors   weights  \
# 0      100000.0  0.000044      False          True           38  distance
# 1       20000.0  0.003086      False         False           10   uniform
# 2      100000.0  0.006342       True         False           44   uniform
# 3       50000.0  0.002863      False         False           36  distance
# 4       20000.0  0.001896      False          True           29   uniform
#
#       metric algorithm
# 0     cosine      auto
# 1  euclidean      auto
# 2  manhattan      auto
# 3  euclidean      auto
# 4  euclidean      auto

# %%
with open(finetuned_model_best_params, "w") as f:
    json.dump(best_params, f, indent=4)

# %%
with open(trial_results_path, "w") as f:
    json.dump(trial_results_df.to_dict(orient="records"), f, indent=4)

# %% [markdown]
# # Train the final model - K-nearest neighbors

# %%
best_params = {}
trial_results = {}

# %%
with open(finetuned_model_best_params, "r") as f:
    best_params = json.load(f)

# %%
with open(trial_results_path, "r") as f:
    trial_results = json.load(f)

# %%
trial_results_df = pd.DataFrame(trial_results)

# %%
top_max_features = best_params["max_features"]
top_min_df = best_params["min_df"]
top_lowercase = best_params["lowercase"]
top_sublinear_tf  = best_params["sublinear_tf"]

top_n_neighbors = best_params["n_neighbors"]
top_weights = best_params["weights"]
top_metric = best_params["metric"]
top_algorithm = best_params["algorithm"]

# %%
print(f"Used hyperparameters \n")
print(f"max_features: {top_max_features}\n")
print(f"min_df: {top_min_df}\n")
print(f"lowercase: {top_lowercase}\n")
print(f"sublinear_tf: {top_sublinear_tf}\n")

print(f"n_neighbors: {top_n_neighbors}\n")
print(f"weights: {top_weights}\n")
print(f"metric: {top_metric}\n")
print(f"algorithm: {top_algorithm}\n")
# Out:
# Used hyperparameters
#
# max_features: 100000
#
# min_df: 0.004017693739287494
#
# lowercase: False
#
# sublinear_tf: True
#
# n_neighbors: 4
#
# weights: distance
#
# metric: cosine
#
# algorithm: auto

# %% [markdown]
# Reconstruct the best vectorizer

# %%
best_vectorizer = build_tfidf_vectorizer(
        max_features=top_max_features,
        min_df=top_min_df, 
        lowercase=top_lowercase,
        sublinear_tf=top_sublinear_tf
        )

# %% [markdown]
# Combine validation and training dataset

# %%
final_train_df = pd.concat(
    [train_data_df, val_data_df],
    ignore_index=True
)

# %% [markdown]
# Fit the vectorizer and create features of training and test data

# %%
train_data, test_data = build_tfidf_features(best_vectorizer, final_train_df, test_data_df)
# Out:
# Fitting vectorizer
#
# Transforming texts with vectorizer

# %% [markdown]
# Compute the absolute differences between the pairs of features in train and test data

# %%
train_data_diff = compute_element_wise_features(train_data)
test_data_diff = compute_element_wise_features(test_data)

# %% [markdown]
# Get the labels for train and test data

# %%
y_train = final_train_df["same"].values
y_test = test_data_df["same"].values

# %% [markdown]
# Fit the classifier

# %%
classifier = KNeighborsClassifier(
    n_neighbors=top_n_neighbors,
    weights=top_weights,
    metric=top_metric,
    algorithm=top_algorithm
)

classifier.fit(train_data_diff, y_train)
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=4, weights='distance')

# %% [markdown]
# Predict the labels for the test data

# %%
y_pred = classifier.predict(test_data_diff)

# %% [markdown]
# Evaluate the results of the final classifier

# %%
top_f1, top_accuracy, top_precision, top_recall = evaluate_results(y_test, y_pred)

print(f"Logging results \n")
print(f"Top f1: {top_f1}\n")
print(f"Top accuracy: { top_accuracy}\n")
print(f"Top precision: {top_precision}\n")
print(f"Top recall: {top_recall}\n")
# Out:
# Logging results
#
# Top f1: 57.07
#
# Top accuracy: 75.95
#
# Top precision: 20.69
#
# Top recall: 32.52

# %% [markdown]
# Save the final vectorizer and classifier

# %%
joblib.dump(best_vectorizer, finetuned_vectorizer_path)
joblib.dump(classifier, finetuned_model_path)
# Out:
# ['/home/jovyan/authorship_verification_dt/data/02_models/traditional/JP_traditional_word_TF-IDF_element-wise_k-nearest_neighbors_best_model.pkl']

# %% [markdown]
# Confusion matrix

# %%
cm_fig = plot_confusion_matrix(y_test , y_pred, f"{representation_type}_{classifier_name}", labels=[False, True])

# %% [markdown]
# Log model information + metrics + results table + confusion matrix

# %%
mlflow.set_experiment("/Users/jiripokorny455@gmail.com/JP_authorship_verification_dt")
with mlflow.start_run(run_name=f"{developer_initials}_{representation_type}_{classifier_name}"):
    mlflow.log_param("gpu_name", gpu_name)
    mlflow.log_param("gpu_vram_gb", gpu_vram_gb)
    
    mlflow.log_param("representation_type", representation_type )
    mlflow.log_param("classifier", classifier_name)
    mlflow.log_table(data=trial_results_df, artifact_file="trial_results.json")
    
    mlflow.log_param("max_features", top_max_features)
    mlflow.log_param("min_df", top_min_df)
    mlflow.log_param("lowercase", top_lowercase)
    mlflow.log_param("sublienar_tf", top_sublinear_tf)
                    
    mlflow.log_param("n_neighbors", top_n_neighbors)
    mlflow.log_param("weights", top_weights)
    mlflow.log_param("metric", top_metric)
    mlflow.log_param("algorithm", top_algorithm)

    mlflow.log_metric("top_accuracy", top_accuracy)
    mlflow.log_metric("top_precision", top_precision)
    mlflow.log_metric("top_recall", top_recall)
    mlflow.log_metric("top_f1", top_f1)

    mlflow.log_figure(cm_fig, "confusion_matrix-test_data.png")
# Out:
# 🏃 View run JP_traditional_word_TF-IDF_element-wise_k-nearest_neighbors at: https://dbc-1ea3ad0e-f504.cloud.databricks.com/ml/experiments/134079680834040/runs/e47919a4a1ac44e69f223136f6855109
# 🧪 View experiment at: https://dbc-1ea3ad0e-f504.cloud.databricks.com/ml/experiments/134079680834040

# %% [markdown]
# # Evaluate model hyperparameters - Random Forest

# %%
classifier_name = "random_forest"

# %%
random_forest_config = ClassifierConfig(
    classifier_object=RandomForestClassifier,
    searched_hyperparameters={
        "n_estimators": lambda trial: trial.suggest_int("n_estimators", 100, 600),
        "max_depth": lambda trial: trial.suggest_int("max_depth", 5, 50),
        "min_samples_split": lambda trial: trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": lambda trial: trial.suggest_int("min_samples_leaf", 1, 10)
    },
    fixed_hyperparameters={
        "n_jobs": -1,        # use all cores
        "random_state": 42   # reproducible forests
    }
)

# %% [markdown]
# Set up the study

# %%
optuna_study_path = f"sqlite:///optuna_study_{developer_initials}_{representation_type}_{classifier_name}"

study = optuna.create_study(
    study_name=f"authorship_verification_{representation_type}_{classifier_name}",
    storage=optuna_study_path,
    direction="maximize",
    load_if_exists=True
)
# Out:
# [I 2025-12-20 13:26:05,064] Using an existing study with name 'authorship_verification_traditional_word_TF-IDF_element-wise_random_forest' instead of creating a new one.

# %%
study.optimize(lambda trial: objective(trial, random_forest_config), n_trials=30-len(study.trials))
# Out:
# Fitting vectorizer
#
# Transforming texts with vectorizer
#
# Logging results
#
# Top f1: 79.6
#
# Top accuracy: 77.88
#
# Top precision: 86.39
#
# Top recall: 81.91
#
# Used hyperparameters
#
# max_features: 100000
#
# min_df: 0.0007349152787492976
#
# lowercase: False
#
# sublinear_tf: True
#
# {'n_estimators': 584, 'max_depth': 38, 'min_samples_split': 4, 'min_samples_leaf': 8, 'n_jobs': -1, 'random_state': 42}
# [I 2025-12-20 14:01:03,251] Trial 29 finished with value: 79.6 and parameters: {'max_features': 100000, 'min_df': 0.0007349152787492976, 'lowercase': False, 'sublinear_tf': True, 'n_estimators': 584, 'max_depth': 38, 'min_samples_split': 4, 'min_samples_leaf': 8}. Best is trial 22 with value: 80.24.

# %% [markdown]
# Save the study insights

# %%
best_trial = study.best_trial
best_params = best_trial.params
best_params.update({
    "n_jobs": -1,        
    "random_state": 42   
})

# %%
trial_results_path = current_dir.parent.parent / "data" / "02_models" / "traditional" / f"{developer_initials}_{representation_type}_{classifier_name}_trial_results.json"
finetuned_model_best_params = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_parameters.json"
finetuned_vectorizer_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_vectorizer.pkl"
finetuned_model_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_model.pkl"

# %% [markdown]
# Load the trial data

# %%
trial_rows = []

for trial in study.trials:
    
    if "results" not in trial.user_attrs:
        continue 
        
    metrics = trial.user_attrs["results"]["metrics"]
    hyper_params = trial.user_attrs["results"]["hyperparameters"]
    classifier_hyper_params = trial.user_attrs["results"]["classifier_hyperparameters"]
    
    row = {
        "trial_number": trial.number,
        "top_f1": metrics["top_f1"],
        "top_accuracy": metrics["top_accuracy"],
        "top_precision": metrics["top_precision"],
        "top_recall": metrics["top_recall"],
        
        **{f"{key}": v for key, v in hyper_params.items()},
        **{f"{key}": v for key, v in classifier_hyper_params.items()},
        
    }
    trial_rows.append(row)

trial_results_df = pd.DataFrame(trial_rows)
trial_results_df.head()
# Out:
#    trial_number  top_f1  top_accuracy  top_precision  top_recall  \
# 0             0   79.04         78.02          84.67       81.21
# 1             1   79.56         78.84          84.44       81.55
# 2             2   78.16         76.96          84.44       80.53
# 3             3   77.56         76.01          84.82       80.17
# 4             4   74.80         72.65          84.82       78.26
#
#    max_features    min_df  lowercase  sublinear_tf  n_estimators  max_depth  \
# 0      100000.0  0.001226      False          True           213         38
# 1      100000.0  0.003614       True          True           436         42
# 2           NaN  0.004202      False         False           260         33
# 3      100000.0  0.009570      False         False           261         23
# 4           NaN  0.008575       True          True           220         14
#
#    min_samples_split  min_samples_leaf  n_jobs  random_state
# 0                  9                 4      -1            42
# 1                  6                 2      -1            42
# 2                 12                 4      -1            42
# 3                  9                 1      -1            42
# 4                 12                 2      -1            42

# %%
with open(finetuned_model_best_params, "w") as f:
    json.dump(best_params, f, indent=4)

# %%
with open(trial_results_path, "w") as f:
    json.dump(trial_results_df.to_dict(orient="records"), f, indent=4)

# %% [markdown]
# # Train the final model - Random forest

# %%
best_params = {}
trial_results = {}

# %%
with open(finetuned_model_best_params, "r") as f:
    best_params = json.load(f)

# %%
with open(trial_results_path, "r") as f:
    trial_results = json.load(f)

# %%
trial_results_df = pd.DataFrame(trial_results)

# %%
top_max_features = best_params["max_features"]
top_min_df = best_params["min_df"]
top_lowercase = best_params["lowercase"]
top_sublinear_tf  = best_params["sublinear_tf"]

top_n_estimators = best_params["n_estimators"]
top_max_depth = best_params["max_depth"]
top_min_samples_split = best_params["min_samples_split"]
top_min_samples_leaf = best_params["min_samples_leaf"]
top_n_jobs = best_params["n_jobs"]
top_random_state = best_params["random_state"]

# %%
print(f"Used hyperparameters \n")
print(f"max_features: {top_max_features}\n")
print(f"min_df: {top_min_df}\n")
print(f"lowercase: {top_lowercase}\n")
print(f"sublinear_tf: {top_sublinear_tf}\n")

print(f"n_estimators: {top_n_estimators}\n")
print(f"max_depth: {top_max_depth}\n")
print(f"min_samples_split: {top_min_samples_split}\n")
print(f"min_samples_leaf: {top_min_samples_leaf}\n")
print(f"n_jobs: {top_n_jobs}\n")
print(f"random_state: {top_random_state}\n")
# Out:
# Used hyperparameters
#
# max_features: 100000
#
# min_df: 0.00211458687946772
#
# lowercase: False
#
# sublinear_tf: True
#
# n_estimators: 529
#
# max_depth: 39
#
# min_samples_split: 2
#
# min_samples_leaf: 8
#
# n_jobs: -1
#
# random_state: 42

# %% [markdown]
# Reconstruct the best vectorizer

# %%
best_vectorizer = build_tfidf_vectorizer(
        max_features=top_max_features,
        min_df=top_min_df, 
        lowercase=top_lowercase,
        sublinear_tf=top_sublinear_tf
        )

# %% [markdown]
# Combine validation and training dataset

# %%
final_train_df = pd.concat(
    [train_data_df, val_data_df],
    ignore_index=True
)

# %% [markdown]
# Fit the vectorizer and create features of training and test data

# %%
train_data, test_data = build_tfidf_features(best_vectorizer, final_train_df, test_data_df)
# Out:
# Fitting vectorizer
#
# Transforming texts with vectorizer

# %% [markdown]
# Compute the absolute differences between the pairs of features in train and test data

# %%
train_data_diff = compute_element_wise_features(train_data)
test_data_diff = compute_element_wise_features(test_data)

# %% [markdown]
# Get the labels for train and test data

# %%
y_train = final_train_df["same"].values
y_test = test_data_df["same"].values

# %% [markdown]
# Fit the classifier

# %%
classifier = RandomForestClassifier(
    n_estimators=top_n_estimators,
    max_depth=top_max_depth,
    min_samples_split=top_min_samples_split,
    min_samples_leaf=top_min_samples_leaf,
    n_jobs=top_n_jobs,
    random_state=top_random_state
)

classifier.fit(train_data_diff, y_train)
# Out:
# RandomForestClassifier(max_depth=39, min_samples_leaf=8, n_estimators=529,
#                        n_jobs=-1, random_state=42)

# %% [markdown]
# Predict the labels for the test data

# %%
y_pred = classifier.predict(test_data_diff)

# %% [markdown]
# Evaluate the results of the final classifier

# %%
top_f1, top_accuracy, top_precision, top_recall = evaluate_results(y_test, y_pred)

print(f"Logging results \n")
print(f"Top f1: {top_f1}\n")
print(f"Top accuracy: { top_accuracy}\n")
print(f"Top precision: {top_precision}\n")
print(f"Top recall: {top_recall}\n")
# Out:
# Logging results
#
# Top f1: 80.04
#
# Top accuracy: 76.51
#
# Top precision: 86.69
#
# Top recall: 81.28

# %% [markdown]
# Save the final vectorizer and classifier

# %%
joblib.dump(best_vectorizer, finetuned_vectorizer_path)
joblib.dump(classifier, finetuned_model_path)
# Out:
# ['/home/jovyan/authorship_verification_dt/data/02_models/traditional/JP_traditional_word_TF-IDF_element-wise_random_forest_best_model.pkl']

# %% [markdown]
# Confusion matrix

# %%
cm_fig = plot_confusion_matrix(y_test , y_pred, f"{representation_type}_{classifier_name}", labels=[False, True])

# %% [markdown]
# Log model information + metrics + results table + confusion matrix

# %%
mlflow.set_experiment("/Users/jiripokorny455@gmail.com/JP_authorship_verification_dt")
with mlflow.start_run(run_name=f"{developer_initials}_{representation_type}_{classifier_name}"):
    mlflow.log_param("gpu_name", gpu_name)
    mlflow.log_param("gpu_vram_gb", gpu_vram_gb)
    
    mlflow.log_param("representation_type", representation_type )
    mlflow.log_param("classifier", classifier_name)
    mlflow.log_table(data=trial_results_df, artifact_file="trial_results.json")
    
    mlflow.log_param("max_features", top_max_features)
    mlflow.log_param("min_df", top_min_df)
    mlflow.log_param("lowercase", top_lowercase)
    mlflow.log_param("sublinear_tf", top_sublinear_tf)
                    
    mlflow.log_param("n_estimators", top_n_estimators)
    mlflow.log_param("max_depth", top_max_depth)
    mlflow.log_param("min_samples_split", top_min_samples_split)
    mlflow.log_param("min_samples_leaf", top_min_samples_leaf)
    mlflow.log_param("n_jobs", top_n_jobs)
    mlflow.log_param("random_state", top_random_state)

    mlflow.log_metric("top_accuracy", top_accuracy)
    mlflow.log_metric("top_precision", top_precision)
    mlflow.log_metric("top_recall", top_recall)
    mlflow.log_metric("top_f1", top_f1)

    mlflow.log_figure(cm_fig, "confusion_matrix-test_data.png")
# Out:
# 🏃 View run JP_traditional_word_TF-IDF_element-wise_random_forest at: https://dbc-1ea3ad0e-f504.cloud.databricks.com/ml/experiments/134079680834040/runs/049984c1258f4aa7862153d519480275
# 🧪 View experiment at: https://dbc-1ea3ad0e-f504.cloud.databricks.com/ml/experiments/134079680834040

# %% [markdown]
# # Evaluate model hyperparameters- XGBoost

# %%
classifier_name = "xgboost"

# %%
xgboost_config = ClassifierConfig(
    classifier_object=XGBClassifier,
    searched_hyperparameters={
        "eta": lambda trial: trial.suggest_float("eta", 0.01, 0.3),
        "max_depth": lambda trial: trial.suggest_int("max_depth", 3, 12),
        "subsample": lambda trial: trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": lambda trial: trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "reg_lambda": lambda trial: trial.suggest_float("reg_lambda", 1e-3, 10.0, log=True),
        "reg_alpha": lambda trial: trial.suggest_float("reg_alpha", 1e-3, 1.0, log=True),
    },
    fixed_hyperparameters={
        "objective": "binary:logistic",
        "eval_metric": "logloss",
        "n_estimators": 300,     
        "tree_method": "auto", 
        "use_label_encoder": False
    }
)

# %% [markdown]
# Set up the study

# %%
optuna_study_path = f"sqlite:///optuna_study_{developer_initials}_{representation_type}_{classifier_name}"

study = optuna.create_study(
    study_name=f"authorship_verification_{representation_type}_{classifier_name}",
    storage=optuna_study_path,
    direction="maximize",
    load_if_exists=True
)
# Out:
# [I 2025-12-20 14:39:13,307] A new study created in RDB with name: authorship_verification_traditional_word_TF-IDF_element-wise_xgboost

# %%
study.optimize(lambda trial: objective(trial, xgboost_config), n_trials=30)
# Out:
# Fitting vectorizer
#
# Transforming texts with vectorizer
# /opt/conda/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [15:06:37] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Logging results
#
# Top f1: 86.32
#
# Top accuracy: 87.72
#
# Top precision: 86.54
#
# Top recall: 87.12
#
# Used hyperparameters
#
# max_features: 20000
#
# min_df: 0.0007522179913709807
#
# lowercase: False
#
# sublinear_tf: False
#
# {'eta': 0.15579696106350288, 'max_depth': 10, 'subsample': 0.6731778695968482, 'colsample_bytree': 0.537976679610612, 'reg_lambda': 0.2036328984392311, 'reg_alpha': 0.24462398119627318, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'n_estimators': 300, 'tree_method': 'auto', 'use_label_encoder': False}
# [I 2025-12-20 15:16:21,323] Trial 0 finished with value: 86.32 and parameters: {'max_features': 20000, 'min_df': 0.0007522179913709807, 'lowercase': False, 'sublinear_tf': False, 'eta': 0.15579696106350288, 'max_depth': 10, 'subsample': 0.6731778695968482, 'colsample_bytree': 0.537976679610612, 'reg_lambda': 0.2036328984392311, 'reg_alpha': 0.24462398119627318}. Best is trial 0 with value: 86.32.
# Fitting vectorizer
#
# Transforming texts with vectorizer
# /opt/conda/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [15:40:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Logging results
#
# Top f1: 84.6
#
# Top accuracy: 85.42
#
# Top precision: 85.86
#
# Top recall: 85.64
#
# Used hyperparameters
#
# max_features: 50000
#
# min_df: 0.0037648337088114067
#
# lowercase: True
#
# sublinear_tf: True
#
# {'eta': 0.06765208317300811, 'max_depth': 10, 'subsample': 0.5205278748904131, 'colsample_bytree': 0.5516586452559997, 'reg_lambda': 0.0011642978961461015, 'reg_alpha': 0.0010215686974005304, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'n_estimators': 300, 'tree_method': 'auto', 'use_label_encoder': False}
# [I 2025-12-20 15:49:48,816] Trial 1 finished with value: 84.6 and parameters: {'max_features': 50000, 'min_df': 0.0037648337088114067, 'lowercase': True, 'sublinear_tf': True, 'eta': 0.06765208317300811, 'max_depth': 10, 'subsample': 0.5205278748904131, 'colsample_bytree': 0.5516586452559997, 'reg_lambda': 0.0011642978961461015, 'reg_alpha': 0.0010215686974005304}. Best is trial 0 with value: 86.32.
# Fitting vectorizer
#
# Transforming texts with vectorizer
# /opt/conda/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [16:13:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Logging results
#
# Top f1: 84.84
#
# Top accuracy: 86.85
#
# Top precision: 84.44
#
# Top recall: 85.63
#
# Used hyperparameters
#
# max_features: None
#
# min_df: 0.007131732637500298
#
# lowercase: False
#
# sublinear_tf: False
#
# {'eta': 0.09773836684574472, 'max_depth': 5, 'subsample': 0.660088947570924, 'colsample_bytree': 0.9306829930391696, 'reg_lambda': 0.0014546982628614884, 'reg_alpha': 0.0026642163033442873, 'objective': 'binary:logistic', 'eval_metric': 'logloss', 'n_estimators': 300, 'tree_method': 'auto', 'use_label_encoder': False}
# [I 2025-12-20 16:15:47,436] Trial 2 finished with value: 84.84 and parameters: {'max_features': None, 'min_df': 0.007131732637500298, 'lowercase': False, 'sublinear_tf': False, 'eta': 0.09773836684574472, 'max_depth': 5, 'subsample': 0.660088947570924, 'colsample_bytree': 0.9306829930391696, 'reg_lambda': 0.0014546982628614884, 'reg_alpha': 0.0026642163033442873}. Best is trial 0 with value: 86.32.
# Fitting vectorizer
#
# Transforming texts with vectorizer
# /opt/conda/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [16:41:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %% [markdown]
# Save the study insights

# %%
best_trial = study.best_trial
best_params = best_trial.params
best_params.update({
    "objective": "binary:logistic",
    "eval_metric": "logloss",
    "n_estimators": 300,     
    "tree_method": "auto", 
    "use_label_encoder": False
})

# %%
trial_results_path = current_dir.parent.parent / "data" / "02_models" / "traditional" / f"{developer_initials}_{representation_type}_{classifier_name}_trial_results.json"
finetuned_model_best_params = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_parameters.json"
finetuned_vectorizer_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_vectorizer.pkl"
finetuned_model_path = current_dir.parent.parent / "data" / "02_models" / "traditional" /f"{developer_initials}_{representation_type}_{classifier_name}_best_model.pkl"

# %% [markdown]
# Load the trial data

# %%
trial_rows = []

for trial in study.trials:
    
    if "results" not in trial.user_attrs:
        continue 
        
    metrics = trial.user_attrs["results"]["metrics"]
    hyper_params = trial.user_attrs["results"]["hyperparameters"]
    classifier_hyper_params = trial.user_attrs["results"]["classifier_hyperparameters"]
    
    row = {
        "trial_number": trial.number,
        "top_f1": metrics["top_f1"],
        "top_accuracy": metrics["top_accuracy"],
        "top_precision": metrics["top_precision"],
        "top_recall": metrics["top_recall"],
        
        **{f"{key}": v for key, v in hyper_params.items()},
        **{f"{key}": v for key, v in classifier_hyper_params.items()},
        
    }
    trial_rows.append(row)

trial_results_df = pd.DataFrame(trial_rows)
trial_results_df.head()

# %%
with open(finetuned_model_best_params, "w") as f:
    json.dump(best_params, f, indent=4)

# %%
with open(trial_results_path, "w") as f:
    json.dump(trial_results_df.to_dict(orient="records"), f, indent=4)

# %% [markdown]
# # Train the final model - XGBoost

# %%
best_params = {}
trial_results = {}

# %%
with open(finetuned_model_best_params, "r") as f:
    best_params = json.load(f)

# %%
with open(trial_results_path, "r") as f:
    trial_results = json.load(f)

# %%
trial_results_df = pd.DataFrame(trial_results)

# %%
top_max_features = best_params["max_features"]
top_min_df = best_params["min_df"]
top_lowercase = best_params["lowercase"]
top_sublinear_tf  = best_params["sublinear_tf"]

top_eta = best_params["eta"]
top_max_depth = best_params["max_depth"]
top_subsample = best_params["subsample"]
top_colsample_bytree = best_params["colsample_bytree"]
top_reg_lambda = best_params["reg_lambda"]
top_reg_alpha = best_params["reg_alpha"]
top_objective = best_params["objective"]
top_eval_metric = best_params["eval_metric"]
top_n_estimators = best_params["n_estimators"]
top_tree_method = best_params["tree_method"]
top_use_label_encoder = best_params["use_label_encoder"]

# %%
print(f"Used hyperparameters \n")
print(f"max_features: {top_max_features}\n")
print(f"min_df: {top_min_df}\n")
print(f"lowercase: {top_lowercase}\n")
print(f"sublinear_tf: {top_sublinear_tf}\n")

print(f"eta: {top_eta}\n")
print(f"max_depth: {top_max_depth}\n")
print(f"subsample: {top_subsample}\n")
print(f"colsample_bytree: {top_colsample_bytree}\n")
print(f"reg_lambda: {top_reg_lambda}\n")
print(f"reg_alpha: {top_reg_alpha}\n")
print(f"objective: {top_objective}\n")
print(f"eval_metric: {top_eval_metric}\n")
print(f"n_estimators: {top_n_estimators}\n")
print(f"tree_method: {top_tree_method}\n")
print(f"use_label_encoder: {top_use_label_encoder}\n")

# %% [markdown]
# Reconstruct the best vectorizer

# %%
best_vectorizer = build_tfidf_vectorizer(
        max_features=top_max_features,
        min_df=top_min_df, 
        lowercase=top_lowercase,
        sublinear_tf=top_sublinear_tf
        )

# %% [markdown]
# Combine validation and training dataset

# %%
final_train_df = pd.concat(
    [train_data_df, val_data_df],
    ignore_index=True
)

# %% [markdown]
# Fit the vectorizer and create features of training and test data

# %%
train_data, test_data = build_tfidf_features(best_vectorizer, final_train_df, test_data_df)

# %% [markdown]
# Compute the absolute differences between the pairs of features in train and test data

# %%
train_data_diff = compute_element_wise_features(train_data)
test_data_diff = compute_element_wise_features(test_data)

# %% [markdown]
# Get the labels for train and test data

# %%
y_train = final_train_df["same"].values
y_test = test_data_df["same"].values

# %% [markdown]
# Fit the classifier

# %%
classifier = XGBClassifier(
    eta=top_eta,
    max_depth=top_max_depth,
    subsample=top_subsample,
    colsample_bytree=top_colsample_bytree,
    reg_lambda=top_reg_lambda,
    reg_alpha=top_reg_alpha,
    objective=top_objective,
    eval_metric=top_eval_metric,
    n_estimators=top_n_estimators,
    tree_method=top_tree_method,
    use_label_encoder=top_use_label_encoder
    
)

classifier.fit(train_data_diff, y_train)

# %% [markdown]
# Predict the labels for the test data

# %%
y_pred = classifier.predict(test_data_diff)

# %% [markdown]
# Evaluate the results of the final classifier

# %%
top_f1, top_accuracy, top_precision, top_recall = evaluate_results(y_test, y_pred)

print(f"Logging results \n")
print(f"Top f1: {top_f1}\n")
print(f"Top accuracy: { top_accuracy}\n")
print(f"Top precision: {top_precision}\n")
print(f"Top recall: {top_recall}\n")

# %% [markdown]
# Save the final vectorizer and classifier

# %%
joblib.dump(best_vectorizer, finetuned_vectorizer_path)
joblib.dump(classifier, finetuned_model_path)

# %% [markdown]
# Confusion matrix

# %%
cm_fig = plot_confusion_matrix(y_test , y_pred, f"{representation_type}_{classifier_name}", labels=[False, True])

# %% [markdown]
# Log model information + metrics + results table + confusion matrix

# %%
mlflow.set_experiment("/Users/jiripokorny455@gmail.com/JP_authorship_verification_dt")
with mlflow.start_run(run_name=f"{developer_initials}_{representation_type}_{classifier_name}"):
    mlflow.log_param("gpu_name", gpu_name)
    mlflow.log_param("gpu_vram_gb", gpu_vram_gb)
    
    mlflow.log_param("representation_type", representation_type )
    mlflow.log_param("classifier", classifier_name)
    mlflow.log_table(data=trial_results_df, artifact_file="trial_results.json")
    
    mlflow.log_param("max_features", top_max_features)
    mlflow.log_param("min_df", top_min_df)
    mlflow.log_param("lowercase", top_lowercase)
    mlflow.log_param("sublinear_tf", top_sublinear_tf)
                    
    mlflow.log_param("eta", top_eta)
    mlflow.log_param("max_depth", top_max_depth)
    mlflow.log_param("subsample", top_subsample)
    mlflow.log_param("colsample_bytree", top_colsample_bytree)
    mlflow.log_param("reg_lambda", top_reg_lambda)
    mlflow.log_param("reg_alpha", top_reg_alpha)
    mlflow.log_param("objective", top_objective)
    mlflow.log_param("eval_metric", top_eval_metric)
    mlflow.log_param("n_estimators", top_n_estimators)
    mlflow.log_param("tree_method", top_tree_method)
    mlflow.log_param("use_label_encoder", top_use_label_encoder)

    mlflow.log_metric("top_accuracy", top_accuracy)
    mlflow.log_metric("top_precision", top_precision)
    mlflow.log_metric("top_recall", top_recall)
    mlflow.log_metric("top_f1", top_f1)

    mlflow.log_figure(cm_fig, "confusion_matrix-test_data.png")
