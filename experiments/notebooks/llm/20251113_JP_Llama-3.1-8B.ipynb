# %%
import os
import time
import json
import pickle
import pandas as pd
import numpy as np

from datetime import datetime
from tqdm import tqdm
from dotenv import load_dotenv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
from huggingface_hub import login
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch
# Out:
# /opt/conda/lib/python3.11/site-packages/torch/utils/_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
# 2025-11-26 11:51:07.368404: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-26 11:51:07.384034: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-26 11:51:07.402711: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-26 11:51:07.457036: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
env_path = '../../conf/local/.env'
load_dotenv(env_path)
huggingface_acess_token = os.getenv("huggingface_jp")

# %%
# !nvidia-smi
# Out:
# Wed Nov 26 11:51:10 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.95.05              Driver Version: 580.95.05      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A40                     Off |   00000000:A3:00.0 Off |                    0 |
# |  0%   55C    P8             40W /  300W |       0MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
torch.cuda.is_available()
# Out:
# True

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %% [markdown]
# # Load dataset

# %%
test_data_path = '../../data/01_processed/pan21-authorship-verification-test.jsonl'

test_data_file_size = os.path.getsize(test_data_path)
test_data = []

with open(test_data_path, 'r') as f:
    with tqdm(total=test_data_file_size, desc="Loading data", unit='B', unit_scale=True) as pbar:
        for line in f:
            test_data.append(json.loads(line))
            pbar.update(len(line.encode('utf-8')))

print(f"\nSuccessfully loaded {len(test_data)} items.")
# Out:
# Loading data: 100%|██████████| 873M/873M [00:04<00:00, 198MB/s]
# Successfully loaded 19999 items.

# %% [markdown]
# Load the data into the pandas dataframe

# %%
test_data_df = pd.DataFrame(test_data)
test_data_df.drop(columns=['fandoms'], inplace=True)
print(test_data_df.head())
# Out:
#                                      id  \
# 0  c28e8b03-c02a-5184-b58a-12dd28b8ca74
# 1  b9326101-6352-56dd-9d1b-1f41466897b7
# 2  e2ac4453-bf54-53f2-bf68-6caae6aacded
# 3  a5e9a289-0999-5764-b597-dc1bf8c21ede
# 4  cb4054b1-d422-58d6-a137-dcfc70100df6
#
#                                                 pair
# 0  [talk because they hadn"t been exposed to comm...
# 1  [Zazuki nodded his head and got to his feet, k...
# 2  ["Oh we did lots of special things. On Christm...
# 3  ["Hey now, at least Shido brings home some mon...
# 4  [It was a mere five minutes" walk from third y...

# %% [markdown]
# Load the testing set labels

# %%
test_data_truth_path = '../../data/01_processed/pan21-authorship-verification-test-truth.jsonl'

test_data_truth_file_size = os.path.getsize(test_data_truth_path)
test_data_truth = []

with open(test_data_truth_path, 'r') as f:
    with tqdm(total=test_data_truth_file_size, desc="Loading data", unit='B', unit_scale=True) as pbar:
        for line in f:
            test_data_truth.append(json.loads(line))
            pbar.update(len(line.encode('utf-8')))

print(f"\nSuccessfully loaded {len(test_data_truth)} items.")
# Out:
# Loading data: 100%|██████████| 1.91M/1.91M [00:00<00:00, 14.1MB/s]
# Successfully loaded 19999 items.

# %% [markdown]
# Load the data into pandas dataframe

# %%
test_data_truth_df = pd.DataFrame(test_data_truth)
test_data_truth_df.drop(columns=['authors'], inplace=True)
print(test_data_truth_df.head())
# Out:
#                                      id   same
# 0  c28e8b03-c02a-5184-b58a-12dd28b8ca74   True
# 1  b9326101-6352-56dd-9d1b-1f41466897b7   True
# 2  e2ac4453-bf54-53f2-bf68-6caae6aacded  False
# 3  a5e9a289-0999-5764-b597-dc1bf8c21ede   True
# 4  cb4054b1-d422-58d6-a137-dcfc70100df6   True

# %% [markdown]
# Combine the dataframes for evaluation

# %%
test_data_full_df = pd.merge(test_data_df, test_data_truth_df, on='id')
test_data_full_reduced_df =  test_data_full_df.head(200)
print(test_data_full_df.head())
# Out:
#                                      id  \
# 0  c28e8b03-c02a-5184-b58a-12dd28b8ca74
# 1  b9326101-6352-56dd-9d1b-1f41466897b7
# 2  e2ac4453-bf54-53f2-bf68-6caae6aacded
# 3  a5e9a289-0999-5764-b597-dc1bf8c21ede
# 4  cb4054b1-d422-58d6-a137-dcfc70100df6
#
#                                                 pair   same
# 0  [talk because they hadn"t been exposed to comm...   True
# 1  [Zazuki nodded his head and got to his feet, k...   True
# 2  ["Oh we did lots of special things. On Christm...  False
# 3  ["Hey now, at least Shido brings home some mon...   True
# 4  [It was a mere five minutes" walk from third y...   True

# %% [markdown]
# # Set up model - llama-3.1-8B

# %% [markdown]
# Log in to huggingface

# %%
login(huggingface_acess_token)

# %% [markdown]
# Load the llama-3.1-8B model

# %%
model_id = "meta-llama/Llama-3.1-8B"
tokenizer = AutoTokenizer.from_pretrained(model_id)

llama3 = pipeline(
    "text-generation",
    model=model_id,
    tokenizer=tokenizer,
    model_kwargs={"device_map": "auto"},
)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
llama3.generation_config.pad_token_id = tokenizer.pad_token_id

# %% [markdown]
# ### Set up prompts

# %% [markdown]
# from [https://github.com/baixianghuang/authorship-llm/blob/main/code/github-verify-llama2-70b.ipynb](https://github.com/baixianghuang/authorship-llm/blob/main/code/github-verify-llama2-70b.ipynb)

# %%
prompt_message = """
Verify if the two input texts below were written by the same author.

Criteria:
- Ignore topic differences.
- Focus strictly on grammatical styles (phrasal verbs, punctuation, rare words, typos).

Input Texts:
"""

# %%
response_message = """
You are an expert linguist and authorship attribution system.

OUTPUT FORMAT:
Return a single JSON object. Do not include markdown formatting (like ```json).
The JSON must strictly follow this schema:
{
  "analysis": "string (brief reasoning)",
  "answer": boolean (true or false)
}
"""

# %%
one_shot_example = """
Example Input:
Text 1: "I gotta go."
Text 2: "I have to depart."

Example Output:
{
  "analysis": "Text 1 uses informal contraction 'gotta', while Text 2 is formal.",
  "answer": false
}
"""

# %% [markdown]
# # Evaluate model

# %% [markdown]
# from [https://github.com/baixianghuang/authorship-llm/blob/main/code/github-verify-llama2-70b.ipynb](https://github.com/baixianghuang/authorship-llm/blob/main/code/github-verify-llama2-70b.ipynb)

# %% [markdown]
# Evaluation function

# %%
def evaluate_results(y_test, y_pred, average='binary'):
    accuracy = round(accuracy_score(y_test, y_pred)*100, 2)
    precision = round(precision_score(y_test, y_pred, average=average)*100, 2)
    recall = round(recall_score(y_test, y_pred, average=average)*100, 2)
    f1 = round(f1_score(y_test, y_pred, average=average)*100, 2)
    return accuracy, precision, recall, f1

# %% [markdown]
# Evaluate model function

# %%
def evaluate_model(test_data_df, llm_model, prompt_message, response_message):
    start_time = time.time()
    verification_results = []

    for i in tqdm(test_data_df.index, desc="Processing rows"):

        resulting_df_row = {}
        resulting_df_row['id']  = test_data_df.loc[i, 'id']
        
        text1, text2 = test_data_df.loc[i, 'pair']

        resulting_df_row['text1'] = text1.strip()
        resulting_df_row['text2'] = text2.strip()
        resulting_df_row['actual_result'] = test_data_df.loc[i, 'same']

        llm_prompt = f"""
        {response_message}
        
        {one_shot_example}
        
        ---
        TASK:
        {prompt_message}
        
        Text 1:
        '''
        {text1}
        '''
        
        Text 2:
        '''
        {text2}
        '''
        
        Genererated JSON Response:
        """
    
        raw_response = llama3(
            llm_prompt,
            do_sample=False,
            temperature=0.01,
            top_p=1,
            max_new_tokens=500
        )
        raw_response_str = raw_response[0]["generated_text"]
        last_close_brace_index = raw_response_str.rfind('}')
        last_open_brace_index = raw_response_str.rfind('{', 0, last_close_brace_index)
        json_string = raw_response_str[last_open_brace_index:last_close_brace_index + 1]
        try:
            response_json = json.loads(json_string)
            resulting_df_row['reasoning'] = response_json['analysis']
            resulting_df_row['prediction'] = response_json['answer']

        except Exception as e:
            resulting_df_row['reasoning'] = json_string
            if 'True' in json_string or 'true' in json_string:
                resulting_df_row['prediction'] = True
            elif 'False' in json_string or 'false' in json_string:
                resulting_df_row['prediction'] = False
            else:
                resulting_df_row['prediction'] = None
        
        verification_results.append(resulting_df_row)

    result_df = pd.DataFrame(verification_results)
    print("--- Execution Time: %s seconds ---" % round(time.time() - start_time, 2))
    return result_df

# %% [markdown]
# Evaluate llama

# %%
result_df = evaluate_model(test_data_full_reduced_df, llama3, prompt_message, response_message)
# Out:
# Processing rows:   0%|          | 0/200 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   0%|          | 1/200 [00:11<36:46, 11.09s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   1%|          | 2/200 [00:21<34:27, 10.44s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   2%|▏         | 3/200 [00:31<33:40, 10.26s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   2%|▏         | 4/200 [00:42<34:49, 10.66s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   2%|▎         | 5/200 [00:53<35:03, 10.79s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   3%|▎         | 6/200 [01:05<36:14, 11.21s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   4%|▎         | 7/200 [01:15<35:06, 10.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   4%|▍         | 8/200 [01:26<34:55, 10.91s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   4%|▍         | 9/200 [01:37<34:52, 10.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   5%|▌         | 10/200 [01:48<34:39, 10.94s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   6%|▌         | 11/200 [01:59<34:08, 10.84s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   6%|▌         | 12/200 [02:10<33:55, 10.83s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   6%|▋         | 13/200 [02:21<34:07, 10.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   7%|▋         | 14/200 [02:32<34:01, 10.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   8%|▊         | 15/200 [02:43<34:14, 11.11s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   8%|▊         | 16/200 [02:54<33:36, 10.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   8%|▊         | 17/200 [03:05<33:24, 10.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:   9%|▉         | 18/200 [03:15<33:02, 10.89s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  10%|▉         | 19/200 [03:26<32:44, 10.85s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  10%|█         | 20/200 [03:37<32:09, 10.72s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  10%|█         | 21/200 [03:47<31:45, 10.64s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  11%|█         | 22/200 [03:58<31:44, 10.70s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  12%|█▏        | 23/200 [04:09<32:02, 10.86s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  12%|█▏        | 24/200 [04:19<31:07, 10.61s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  12%|█▎        | 25/200 [04:32<33:08, 11.37s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  13%|█▎        | 26/200 [04:43<32:26, 11.19s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  14%|█▎        | 27/200 [04:54<31:36, 10.96s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  14%|█▍        | 28/200 [05:06<32:51, 11.46s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  14%|█▍        | 29/200 [05:18<32:59, 11.58s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  15%|█▌        | 30/200 [05:29<32:07, 11.34s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  16%|█▌        | 31/200 [05:39<30:55, 10.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  16%|█▌        | 32/200 [05:49<29:46, 10.64s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  16%|█▋        | 33/200 [06:00<30:04, 10.81s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  17%|█▋        | 34/200 [06:11<30:14, 10.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  18%|█▊        | 35/200 [06:22<29:45, 10.82s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  18%|█▊        | 36/200 [06:32<29:08, 10.66s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  18%|█▊        | 37/200 [06:42<28:10, 10.37s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  19%|█▉        | 38/200 [06:52<27:42, 10.26s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  20%|█▉        | 39/200 [07:02<27:32, 10.27s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  20%|██        | 40/200 [07:12<27:31, 10.32s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  20%|██        | 41/200 [07:23<27:47, 10.49s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  21%|██        | 42/200 [07:34<27:41, 10.52s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  22%|██▏       | 43/200 [07:45<27:42, 10.59s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  22%|██▏       | 44/200 [07:56<28:18, 10.89s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  22%|██▎       | 45/200 [08:06<27:11, 10.53s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  23%|██▎       | 46/200 [08:16<26:36, 10.37s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  24%|██▎       | 47/200 [08:26<26:28, 10.38s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  24%|██▍       | 48/200 [08:37<26:35, 10.50s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  24%|██▍       | 49/200 [08:49<27:11, 10.80s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  25%|██▌       | 50/200 [08:59<26:50, 10.74s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  26%|██▌       | 51/200 [09:10<26:40, 10.74s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  26%|██▌       | 52/200 [09:21<26:31, 10.75s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  26%|██▋       | 53/200 [09:31<26:06, 10.66s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  27%|██▋       | 54/200 [09:42<26:09, 10.75s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  28%|██▊       | 55/200 [09:53<25:58, 10.75s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  28%|██▊       | 56/200 [10:05<26:29, 11.04s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  28%|██▊       | 57/200 [10:15<25:38, 10.76s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  29%|██▉       | 58/200 [10:26<25:55, 10.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  30%|██▉       | 59/200 [10:37<25:47, 10.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  30%|███       | 60/200 [10:47<25:00, 10.72s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  30%|███       | 61/200 [10:58<24:57, 10.77s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  31%|███       | 62/200 [11:09<24:31, 10.66s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  32%|███▏      | 63/200 [11:20<24:44, 10.83s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  32%|███▏      | 64/200 [11:30<24:21, 10.75s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  32%|███▎      | 65/200 [11:41<24:12, 10.76s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  33%|███▎      | 66/200 [11:52<23:54, 10.71s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  34%|███▎      | 67/200 [12:02<23:32, 10.62s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  34%|███▍      | 68/200 [12:15<24:34, 11.17s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  34%|███▍      | 69/200 [12:26<24:12, 11.09s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  35%|███▌      | 70/200 [12:37<23:59, 11.07s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  36%|███▌      | 71/200 [12:48<23:47, 11.07s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  36%|███▌      | 72/200 [12:58<23:25, 10.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  36%|███▋      | 73/200 [13:09<22:49, 10.78s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  37%|███▋      | 74/200 [13:19<22:24, 10.67s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  38%|███▊      | 75/200 [13:30<22:04, 10.59s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  38%|███▊      | 76/200 [13:40<22:05, 10.69s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  38%|███▊      | 77/200 [13:51<22:04, 10.77s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  39%|███▉      | 78/200 [14:02<21:59, 10.81s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  40%|███▉      | 79/200 [14:14<22:09, 10.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  40%|████      | 80/200 [14:24<21:44, 10.87s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  40%|████      | 81/200 [14:36<21:57, 11.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  41%|████      | 82/200 [14:47<22:01, 11.20s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  42%|████▏     | 83/200 [14:58<21:34, 11.07s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  42%|████▏     | 84/200 [15:09<21:29, 11.12s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  42%|████▎     | 85/200 [15:21<21:31, 11.23s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  43%|████▎     | 86/200 [15:32<21:10, 11.14s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  44%|████▎     | 87/200 [15:42<20:34, 10.93s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  44%|████▍     | 88/200 [15:53<20:12, 10.82s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  44%|████▍     | 89/200 [16:04<20:04, 10.85s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  45%|████▌     | 90/200 [16:15<19:55, 10.87s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  46%|████▌     | 91/200 [16:25<19:41, 10.84s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  46%|████▌     | 92/200 [16:36<19:27, 10.81s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  46%|████▋     | 93/200 [16:48<19:36, 10.99s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  47%|████▋     | 94/200 [16:59<19:26, 11.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  48%|████▊     | 95/200 [17:10<19:17, 11.02s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  48%|████▊     | 96/200 [17:20<18:59, 10.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  48%|████▊     | 97/200 [17:32<19:12, 11.19s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  49%|████▉     | 98/200 [17:43<18:42, 11.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  50%|████▉     | 99/200 [17:54<18:31, 11.00s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  50%|█████     | 100/200 [18:04<17:58, 10.79s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  50%|█████     | 101/200 [18:15<17:55, 10.87s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  51%|█████     | 102/200 [18:26<17:41, 10.83s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  52%|█████▏    | 103/200 [18:36<17:22, 10.75s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  52%|█████▏    | 104/200 [18:47<16:58, 10.61s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  52%|█████▎    | 105/200 [18:58<17:07, 10.81s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  53%|█████▎    | 106/200 [19:08<16:37, 10.61s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  54%|█████▎    | 107/200 [19:19<16:27, 10.61s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  54%|█████▍    | 108/200 [19:29<16:02, 10.46s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  55%|█████▍    | 109/200 [19:40<16:08, 10.64s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  55%|█████▌    | 110/200 [19:50<15:40, 10.45s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  56%|█████▌    | 111/200 [20:01<15:50, 10.68s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  56%|█████▌    | 112/200 [20:12<15:37, 10.65s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  56%|█████▋    | 113/200 [20:22<15:29, 10.69s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  57%|█████▋    | 114/200 [20:33<15:11, 10.60s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  57%|█████▊    | 115/200 [20:43<14:48, 10.46s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  58%|█████▊    | 116/200 [20:56<15:37, 11.16s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  58%|█████▊    | 117/200 [21:07<15:22, 11.12s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  59%|█████▉    | 118/200 [21:17<14:58, 10.95s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  60%|█████▉    | 119/200 [21:29<14:53, 11.03s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  60%|██████    | 120/200 [21:40<14:47, 11.10s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  60%|██████    | 121/200 [21:51<14:35, 11.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  61%|██████    | 122/200 [22:02<14:31, 11.17s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  62%|██████▏   | 123/200 [22:14<14:21, 11.19s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  62%|██████▏   | 124/200 [22:24<14:01, 11.08s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  62%|██████▎   | 125/200 [22:34<13:28, 10.78s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  63%|██████▎   | 126/200 [22:46<13:44, 11.15s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  64%|██████▎   | 127/200 [22:57<13:21, 10.98s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  64%|██████▍   | 128/200 [23:07<12:57, 10.80s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  64%|██████▍   | 129/200 [23:19<12:58, 10.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  65%|██████▌   | 130/200 [23:30<12:58, 11.12s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  66%|██████▌   | 131/200 [23:40<12:16, 10.68s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  66%|██████▌   | 132/200 [23:51<12:07, 10.71s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  66%|██████▋   | 133/200 [24:01<11:41, 10.47s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  67%|██████▋   | 134/200 [24:11<11:32, 10.50s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  68%|██████▊   | 135/200 [24:22<11:23, 10.51s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  68%|██████▊   | 136/200 [24:32<11:10, 10.48s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  68%|██████▊   | 137/200 [24:43<11:08, 10.61s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  69%|██████▉   | 138/200 [24:54<10:59, 10.64s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  70%|██████▉   | 139/200 [25:04<10:45, 10.57s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  70%|███████   | 140/200 [25:14<10:21, 10.35s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  70%|███████   | 141/200 [25:25<10:17, 10.47s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  71%|███████   | 142/200 [25:35<10:05, 10.44s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  72%|███████▏  | 143/200 [25:46<10:08, 10.68s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  72%|███████▏  | 144/200 [25:57<09:53, 10.60s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  72%|███████▎  | 145/200 [26:07<09:41, 10.58s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  73%|███████▎  | 146/200 [26:18<09:33, 10.63s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  74%|███████▎  | 147/200 [26:29<09:25, 10.66s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  74%|███████▍  | 148/200 [26:40<09:27, 10.92s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  74%|███████▍  | 149/200 [26:51<09:13, 10.86s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  75%|███████▌  | 150/200 [27:01<08:54, 10.69s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  76%|███████▌  | 151/200 [27:12<08:42, 10.65s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  76%|███████▌  | 152/200 [27:23<08:37, 10.77s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Processing rows:  76%|███████▋  | 153/200 [27:34<08:26, 10.77s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.

# %% [markdown]
# Export the results file

# %%
date_str = datetime.now().strftime("%Y%m%d_%H%M")
print(date_str)
file_path = f"../../results/{date_str}_JP-third_prototype_Llama-3.1-8B-Instruct_results.csv"
result_df.to_csv(file_path, index=False)

# %%
imported_result_df = pd.read_csv(file_path)
cleaned_df = imported_result_df.dropna()

# %%
y_test = cleaned_df['actual_result'].to_list()
y_pred = cleaned_df['prediction'].to_list()

# %%
accuracy, precision, recall, f1 = evaluate_results(y_test, y_pred)
print(f"The results of evaluation are: \n Accuracy: {accuracy} \n Precision: {precision} \n Recall: {recall} \n F1 score: {f1}")
